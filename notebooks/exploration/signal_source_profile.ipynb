# %% [markdown]
# # Signal Source Profile
#
# This notebook profiles source freshness, signal volume, and organization-name coverage using the sample data contracts.

# %%
import json
from pathlib import Path

signals = json.loads(Path('../../sample_data/raw/mock_signals.json').read_text())
[(item['source'], item['signal_type']) for item in signals]
