# %% [markdown]
# # Investor Matching Validation
#
# This notebook reviews investor targeting outputs and relationship strength values.

# %%
investors = [('Summit Peak Ventures', 0.83), ('Cedar Capital', 0.79)]
sorted(investors, key=lambda item: item[1], reverse=True)
