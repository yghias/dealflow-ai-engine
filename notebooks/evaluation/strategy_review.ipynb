# %% [markdown]
# # Strategy Review
#
# This notebook reviews ranked queue output alongside strategy generation fixtures and downstream CRM activity.

# %%
import json
from pathlib import Path

queue = json.loads(Path('../../sample_data/curated/ranked_signal_queue.json').read_text())
queue
