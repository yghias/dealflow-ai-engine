# %% [markdown]
# # Company Scoring Validation
#
# This notebook inspects score distributions, duplicate company records, and missing fields.

# %%
scores = [0.82, 0.74, 0.91, 0.33]
min(scores), max(scores), sum(scores) / len(scores)
